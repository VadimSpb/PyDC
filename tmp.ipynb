# %%
import numpy as np
import pandas as pd

# %%
data_train = pd.read_csv('C:/Users/User/GoogleDrive/Learning/geekbrains/1_PyDC01/Kurs_project/train.csv')

# %%
data_train.shape
# Out:
# (10000, 20)

# %%
data_train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
data_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_fomat = 'svg'

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data_train['Rooms'], data_train['Square'])
plt.xlabel('Rooms')
plt.ylabel('Square')
# Out:
# Text(0, 0.5, 'Square')

# %%
# поищем адекватные замены для данных по комнатам

# %%
data_train.loc[data_train['Rooms'] > 5, :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 8849  14865           9   10.0  60.871266   38.420681           10.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377         22.0       2002   0.090799         B         B        74
# 1454        17.0       2014   0.007122         B         B         1
# 2170         9.0       1969   0.033494         B         B        66
# 8849         2.0       1994   0.161532         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 377      19083         2           NaN            5       15       B
# 1454       264         0           NaN            0        1       B
# ...

# %%
# среднее значение комнат для каждой площади
square_stat = data_train.groupby(['Rooms'])['Square'].mean()
square_stat
# Out:
# Rooms
# 0.0      81.620358
# 1.0      41.323277
# 2.0      56.788214
# 3.0      76.903234
# 4.0      98.377544
# 5.0     122.614941
# 6.0      59.414334
# 10.0     59.964120
# 19.0     42.006046
# Name: Square, dtype: float64

# %%
data_train.loc[data_train['Rooms'] == 0, :].describe()
# Out:
#                  Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  \
# count      8.000000    8.000000    8.0    8.000000    5.000000       8.000000
# mean    5615.500000   32.125000    0.0   81.620358   90.558075       1.125000
# std     4375.422298   23.763342    0.0   66.813920   86.300012       3.181981
# min      456.000000    6.000000    0.0    2.377248    0.873147       0.000000
# 25%     2561.750000   27.000000    0.0   41.017440   19.345131       0.000000
# 50%     5270.500000   27.000000    0.0   65.487474   85.125471       0.000000
# 75%     8298.500000   27.250000    0.0  100.428886  136.215499       0.000000
# max    12638.000000   88.000000    0.0  212.932361  211.231125       9.000000
#
#            Floor  HouseFloor    HouseYear  Ecology_1  Social_1     Social_2  \
# count   8.000000    8.000000     8.000000   8.000000   8.00000     8.000000
# mean    6.750000    4.625000  1991.125000   0.152049  14.75000  3180.250000
# ...

# %%
data_train_0rooms = data_train.loc[data_train['Rooms'] == 0, :]
data_train_0rooms = pd.DataFrame(data_train_0rooms)
data_train_0rooms.sort_values(by=['Price'], inplace=True, ascending=False)
data_train_0rooms
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1981         3.0       2008   0.211401         B         B         9
# 1397         3.0       2016   0.075424         B         B        11
# ...

# %%
# проверяем гипотезу о студиях
plt.figure(figsize=(8, 6))
plt.scatter(data_train_0rooms['Price'], data_train_0rooms['Square'] )
plt.xlabel('price')
plt.ylabel('Square')
# Out:
# Text(0, 0.5, 'Square')

# %%
# не студии. так что:
#Найдем максимально коррелируемый признак:
data_train_corr = data_train.corr()
data_train_corr['Rooms'].sort_values()
# Out:
# Ecology_1       -0.032347
# HouseFloor      -0.029302
# HouseYear       -0.010612
# Id              -0.005847
# Floor           -0.000665
# KitchenSquare    0.005123
# Social_3         0.012811
# Healthcare_1     0.042857
# Shops_1          0.053618
# Helthcare_2      0.063557
# Social_2         0.071335
# DistrictId       0.071432
# Social_1         0.075980
# LifeSquare       0.131336
# Price            0.550291
# Square           0.662893
# Rooms            1.000000
# Name: Rooms, dtype: float64

# %%
tmp_predict = pd.DataFrame(data_train.loc[data_train['Rooms'] == 0, :], columns=['Rooms'])

# %%
# сделаем выборку по площади и цене и подставим средние значения ? ЛИНЕЙНАЯ РЕГРЕССИЯ?..

feature_names = data_train.keys()

tmp_x = pd.DataFrame(data_train.loc[data_train['Rooms'] !=0, :], columns=['Price', 'Square','Rooms'])
tmp_y = pd.DataFrame(data_train.loc[data_train['Rooms'] ==0, :], columns=['Rooms'])

# %%
from sklearn.model_selection import train_test_split
tmp_x_train, tmp_x_test, tmp_y_train, tmp_y_test = train_test_split(tmp_x, tmp_y, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-3d23b11b19f9> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 tmp_x_train, tmp_x_test, tmp_y_train, tmp_y_test = train_test_split(tmp_x, tmp_y, test_size=0.3, random_state=42)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(tmp_x_train, tmp_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
tmp_y = pd.DataFrame(data_train.loc[data_train['Rooms'] == 0, :], columns=['Rooms'])
